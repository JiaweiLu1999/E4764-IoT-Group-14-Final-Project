# %%
import face_recognition
import picamera
import numpy as np
from PIL import Image
import pyrebase

# %%
def set_up():
config = {
  "apiKey": "AIzaSyC_UQjYvDX1uNGOo4p0hHsfi-egz1EV_OE",
  "authDomain": "vending-login.firebaseapp.com",
  "databaseURL": "https://vending-login-default-rtdb.firebaseio.com",
  "projectId": "vending-login",
  "storageBucket": "vending-login.appspot.com", 
  "serviceAccount": "vending-login-firebase-adminsdk-jw34y-d1b690e986.json"
}

firebase = pyrebase.initialize_app(config)
# Get a reference to the auth service
auth = firebase.auth()

# Get a reference to the database service
db = firebase.database()
# All files in firestore storage.
all_files = storage.child("faces/").list_files()
for file in all_files:
    print(file.name)
    file.download_to_filename(file.name+".jpg")


face_path = os.listdir("faces/")
dataset_encodings = []
dataset_files = []
for file in face_path:
    if (file[-4:] == ".jpg"):
        dataset_image = face_recognition.load_image_file("faces/"+file)
        dataset_encoding = face_recognition.face_encodings(dataset_image)[0]
        dataset_encodings.append(dataset_encoding)
        dataset_files.append(file)
# Out:
# faces/BXX1PBsb5OYGzquXIGeQadx8bax1
# faces/FQGV1Irp4Bhf5YYVTHb5o8wwqy82
# faces/iJDtdobbDQOnGXzP77eirBNGbyQ2

# %%
user = auth.sign_in_with_email_and_password("jl5999@columbai.edu", "180011")

# %%
# Initialize some variables
face_locations = []
face_encodings = []
# Find all the faces and face encodings in the current frame of video
face_locations = face_recognition.face_locations(output)
print("Found {} faces in image.".format(len(face_locations)))
face_encodings = face_recognition.face_encodings(output, face_locations)

# Loop over each face found in the frame to see if it's someone we know.
for i in range(len(face_encodings)):
    for j in range(len(dataset_encodings)):
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces([dataset_encodings[j]], face_encodings[i], tolerance = 0.4)
        name = "<Unknown Person>"
        if match[0]:
            name = dataset_files[j]
            print(name)
# Out:
# Found 1 faces in image.
# iJDtdobbDQOnGXzP77eirBNGbyQ2.jpg
# Di Wu.jpg

# %%
camera = picamera.PiCamera()
camera.resolution = (320, 240)
output = np.empty((240, 320, 3), dtype=np.uint8)

# %%
camera.capture(output, format="rgb")
img = Image.fromarray(output)
img
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0xAA56ABC8>

# %%
# Load a sample picture and learn how to recognize it.
print("Loading known face image(s)")
obama_image = face_recognition.load_image_file("obama_small.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Initialize some variables
face_locations = []
face_encodings = []

while True:
    print("Capturing image.")
    # Grab a single frame of video from the RPi camera as a numpy array
    camera.capture(output, format="rgb")

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(output)
    print("Found {} faces in image.".format(len(face_locations)))
    face_encodings = face_recognition.face_encodings(output, face_locations)

    # Loop over each face found in the frame to see if it's someone we know.
    for face_encoding in face_encodings:
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces([obama_face_encoding], face_encoding)
        name = "<Unknown Person>"

        if match[0]:
            name = "Barack Obama"

        print("I see someone named {}!".format(name))

# %%
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_2198/3394213390.py in <module>
#       3 def face_login():
#       4     x = 0
# ----> 5 app = App(title="Smart Vending Machine", layout="grid")
#       6 app.full_screen = True
#       7
#
# /usr/local/lib/python3.9/dist-packages/guizero/App.py in __init__(self, title, width, height, layout, bg, visible)
#      42         # If this is the first app to be created, create Tk
#      43         if App._main_app is None:
# ---> 44             tk = Tk()
#      45             App._main_app = self
#      46             # apply tk options
#
# /usr/lib/python3.9/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2268                 baseName = baseName + ext
#    2269         interactive = False
# -> 2270         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2271         if useTk:
#    2272             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
# Importing Image class from PIL module
from PIL import Image
 
# Opens a image in RGB mode
im = Image.open('items/doritos.png')
 
newsize = (200, 200)
im1 = im.resize(newsize)
# Shows the image in image viewer
im1.save('items/1.png')

# %%
def dataset_update_init(dataset_path):
    print("Initializing dataset...")
    dataset_encodings = []
    dataset_files = []
    dataset_filename = os.listdir(dataset_path)
    for file in dataset_filename:
        if file[-4:] == ".jpg":
            print(dataset_path + file)
            dataset_image = face_recognition.load_image_file(dataset_path + file)
            dataset_encoding = face_recognition.face_encodings(dataset_image)[0]
            dataset_encodings.append(dataset_encoding)
            dataset_files.append(file)
    
    return dataset_encodings, dataset_files

# %%
import os
root_dir = os. getcwd() 
dataset_path = root_dir + '/faces/'
dataset_filename = os.listdir(dataset_path)

# %%
dataset_image = face_recognition.load_image_file(dataset_path + dataset_filename[0])

# %%
dataset_encoding = face_recognition.face_encodings(dataset_image)[0]
